# %% [markdown]
# # Nashville Housing Data

# %%
import sqlite3
import csv

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1. Reading CSV file
# We can use *pd.read_csv()* function to read a csv file and convert into panda dataframe.
# In the example below, we are assuming that the "nashville_housing.csv" is stored in the
# current folder (i.e. in the same folder where this notebook is stored)
#
# ```python
# df = pd.read_csv("nashville_housing.csv")
# ```
#
# ### Q1a. [10pts] Read the input file using the *pd.read_csv()* function and store inside a panda dataframe

# %%
# YOUR CODE HERE
df = pd.read_csv("nashville_housing.csv")
del df['Unnamed: 0']
del df['Unnamed: 0.1']
df.head()
# Out:
#           Parcel ID           Land Use   Property Address Suite/ Condo   #  \
# 0  105 03 0D 008.00  RESIDENTIAL CONDO    1208  3RD AVE S                8
# 1   105 11 0 080.00      SINGLE FAMILY   1802  STEWART PL              NaN
# 2   118 03 0 130.00      SINGLE FAMILY  2761  ROSEDALE PL              NaN
# 3   119 01 0 479.00      SINGLE FAMILY  224  PEACHTREE ST              NaN
# 4   119 05 0 186.00      SINGLE FAMILY      316  LUTIE ST              NaN
#
#   Property City Sale Date  Sale Price   Legal Reference Sold As Vacant  \
# 0     NASHVILLE   1/24/13      132000  20130128-0008725             No
# 1     NASHVILLE   1/11/13      191500  20130118-0006337             No
# 2     NASHVILLE   1/18/13      202000  20130124-0008033             No
# 3     NASHVILLE   1/18/13       32000  20130128-0008863             No
# 4     NASHVILLE   1/23/13      102000  20130131-0009929             No
#
#   Multiple Parcels Involved in Sale  ... Building Value Total Value  \
# ...

# %% [markdown]
# ## Part 2. Data selection
# In this part, your task is to write codes to filter the dataset by selecting rows whose column match some conditions.

# %% [markdown]
# ### Q2a. [10pts] Select and show all the houses that were sold for more than 1 000 000 USD.

# %%
# YOUR CODE HERE
df[df['Sale Price'] > 1000000]
# Out:
#               Parcel ID           Land Use         Property Address  \
# 140     117 10 0 015.00      SINGLE FAMILY      2205  WOODMONT BLVD
# 193     144 06 0 010.00      SINGLE FAMILY      4400  CHICKERING LN
# 194     144 06 0 039.00    VACANT RES LAND            0  MILLER CIR
# 202     158 03 0 003.00      SINGLE FAMILY        2001  CROMWELL DR
# 203    158 11 0A 006.00      SINGLE FAMILY    340  WHITE SWANS XING
# 204     159 00 0 261.00      SINGLE FAMILY  5442  GRANNY WHITE PIKE
# 205    159 07 0A 011.00      SINGLE FAMILY     5032  HIGH VALLEY DR
# 206     160 02 0 012.00      SINGLE FAMILY          824  REDWOOD DR
# 527    104 02 1G 003.00  RESIDENTIAL CONDO      3123  PARTHENON AVE
# 534     104 09 0 238.00      SINGLE FAMILY         205  BOWLING AVE
# 536    104 14 0H 080.00      SINGLE FAMILY          34  OLD CLUB CT
# 561     116 10 0 074.00      SINGLE FAMILY       224  DEER PARK CIR
# 573     117 09 0 057.00      SINGLE FAMILY            2430  BEAR RD
# ...

# %% [markdown]
# ### Q2b. [10pts] Select and show all the houses that are located in Brentwood

# %%
# YOUR CODE HERE
df[df['Property City'].str.upper() == 'BRENTWOOD']
# Out:
#               Parcel ID           Land Use          Property Address  \
# 25     160 11 0A 088.00      SINGLE FAMILY      5510  HEARTHSTONE LN
# 26     160 16 0B 019.00      SINGLE FAMILY  6144  BRENTWOOD CHASE DR
# 35     171 03 0B 082.00  RESIDENTIAL CONDO     641  OLD HICKORY BLVD
# 36     171 03 0B 193.00  RESIDENTIAL CONDO     641  OLD HICKORY BLVD
# 37     171 03 0B 212.00  RESIDENTIAL CONDO     601  OLD HICKORY BLVD
# ...                 ...                ...                       ...
# 55531  181 03 0A 301.00      SINGLE FAMILY           8020 MANDAN  DR
# 55532  181 10 0D 019.00      SINGLE FAMILY       477 HIGH POINT  TER
# 55533  181 10 0E 012.00      SINGLE FAMILY            5115 ANDER  DR
# 55534  181 14 0A 107.00  RESIDENTIAL CONDO         8603 ALTESSE  WAY
# 55535  181 14 0A 217.00  RESIDENTIAL CONDO         8728 AMBONNAY  DR
#
#       Suite/ Condo   # Property City Sale Date  Sale Price   Legal Reference  \
# ...

# %% [markdown]
# ### Q2c. [10pts] How many houses  were sold in 2014?

# %%
# YOUR CODE HERE
import datetime
df['Year'] = pd.DatetimeIndex(df['Sale Date']).year

# %%
##another way you can do it
#cond = df['Sale Date'].str.endswith('14')

# %%
sold_fourteen = df[df['Year'] == 2014]
print("There were", sold_fourteen['Year'].count(), "houses sold in 2014.")
# Out:
# There were 14297 houses sold in 2014.

# %% [markdown]
# ### Q2d. [10pts] How many houses  in the Antioch area were sold in 2015?

# %%
# YOUR CODE HERE
ft = df[(df['Year'] == 2015)] 
ft_ant = ft[ft['Property City'].str.upper() == 'ANTIOCH']
print("There were", ft_ant['Year'].count(), "houses sold in the Antioch area in 2015.")
# Out:
# There were 2029 houses sold in the Antioch area in 2015.

# %%
##another way you can do it: Two steps
#First, select all records in Antioch
##cond1 = df['Property City'].str.upper() == 'ANTIOCH'
##antioch_houses = df[cond1]
#Second, select all houses sold in 2015
##cond2 = df['Sale Date'].str.endswith('15')
##len(antioch_houses[cond2])

# %%
##another way to do it in one line
##df[(df['Year'] == 2015) & (df['Property City'] == 'ANTIOCH')]['Year'].count()

##here the letters 'and' are boolean and the symbol '&'
# Out:
# 2029

# %% [markdown]
# ### Q2e. [10pts] What was the average house price in 2013?

# %%
# YOUR CODE HERE
tt = df[df['Year'] == 2013]
sum = tt['Sale Price'].sum()
count = tt['Year'].count()
avg = sum/count
print("The average house price in 2013 was $%.2f" % avg)
# Out:
# The average house price in 2013 was $245489.80

# %%
tt['Sale Price'].median()
##tt['Sale Price'].describe()
# Out:
# 180000.0

# %%
tt['Sale Price'].mean()
# Out:
# 245489.79739138097

# %% [markdown]
# ### Q2f. [10pts] What was the average price of 4-bedroom houses in the Nashville area between 2013 and 2016?

# %%
# YOUR CODE HERE
nash = df[df['Property City'].str.upper() == 'NASHVILLE']
four_nash = nash[nash['Bedrooms'] == 4]
sum = four_nash['Sale Price'].sum()
count = four_nash['Year'].count()
avg = sum/count
print("The average price of a 4-bedroom house in the Nashville area between 2013 and 2016 was $%.2f." % avg )
# Out:
# The average price of a 4-bedroom house in the Nashville area between 2013 and 2016 was $436825.34.

# %% [markdown]
# ### Q2g. [10pts] Remove the State, Image, and Parcel ID columns

# %%
# YOUR CODE HERE
del df['State']
del df['image']
del df['Parcel ID']
df.columns
# Out:
# Index(['Land Use', 'Property Address', 'Suite/ Condo   #', 'Property City',
#        'Sale Date', 'Sale Price', 'Legal Reference', 'Sold As Vacant',
#        'Multiple Parcels Involved in Sale', 'Owner Name', 'Address', 'City',
#        'Acreage', 'Tax District', 'Neighborhood', 'Land Value',
#        'Building Value', 'Total Value', 'Finished Area', 'Foundation Type',
#        'Year Built', 'Exterior Wall', 'Grade', 'Bedrooms', 'Full Bath',
#        'Half Bath', 'Year'],
#       dtype='object')

# %% [markdown]
# ### Q2h. [10pts] Remove all records that have at least one missing value

# %%
# YOUR CODE HERE
clean = df.dropna()
clean
# Out:
#             Land Use        Property Address Suite/ Condo   # Property City  \
# 7822   ZERO LOT LINE        1129  CLIFTON LN              3-B     NASHVILLE
# 24933  ZERO LOT LINE  1245  OLD HICKORY BLVD              2-A     BRENTWOOD
#
#       Sale Date  Sale Price   Legal Reference Sold As Vacant  \
# 7822     9/4/13      201000  20130909-0094904             No
# 24933  12/12/14      275000  20141217-0115474             No
#
#       Multiple Parcels Involved in Sale                     Owner Name  ...  \
# 7822                                 No       CRUTCHFIELD, BILL & LEAH  ...
# 24933                                No  RONVEAUX, KAY B. & RICHARD C.  ...
#
#       Total Value Finished Area  Foundation Type Year Built  Exterior Wall  \
# 7822     209700.0        1332.0            CRAWL     1984.0          BRICK
# 24933    292000.0        2333.0            CRAWL     1985.0          FRAME
#
#        Grade  Bedrooms  Full Bath  Half Bath  Year
# ...

# %% [markdown]
# ### Q3i. [10pts] How many records are left in the dataframe?

# %%
# YOUR CODE HERE
print("There are ", clean['Property Address'].count(), " records left in the dataframe.")
# Out:
# There are  2  records left in the dataframe.
